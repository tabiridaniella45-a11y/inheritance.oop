# %%
# Parent Class
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display_info(self):
        print(f"Name: {self.name}")
        print(f"Age: {self.age}")


# Child Class - Student
class Student(Person):
    def __init__(self, name, age, student_id):
        super().__init__(name, age)   # Initialize inherited attributes
        self.student_id = student_id

    # Overriding display_info()
    def display_info(self):
        super().display_info()
        print(f"Student ID: {self.student_id}")

    def enroll_course(self, course):
        print(f"{self.name} has enrolled in {course}.")


# Child Class - Lecturer
class Lecturer(Person):
    def __init__(self, name, age, employee_id):
        super().__init__(name, age)   # Initialize inherited attributes
        self.employee_id = employee_id

    def teach_course(self, course):
        print(f"{self.name} is teaching {course}.")


# Creating objects
student1 = Student("Matthew Cobbinah", 21, "STU001")
lecturer1 = Lecturer("Dr. Mensah", 45, "EMP101")

# Demonstrating inherited display_info() method
print("===== STUDENT INFORMATION =====")
student1.display_info()
student1.enroll_course("Object-Oriented Programming")

print("\n===== LECTURER INFORMATION =====")
lecturer1.display_info()
print(f"Employee ID: {lecturer1.employee_id}")
lecturer1.teach_course("Object-Oriented Programming")
# Out:
# ===== STUDENT INFORMATION =====
# Name: Matthew Cobbinah
# Age: 21
# Student ID: STU001
# Matthew Cobbinah has enrolled in Object-Oriented Programming.
#
# ===== LECTURER INFORMATION =====
# Name: Dr. Mensah
# Age: 45
# Employee ID: EMP101
# Dr. Mensah is teaching Object-Oriented Programming.
